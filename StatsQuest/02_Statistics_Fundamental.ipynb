# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 40/100
#
# import

# %%
# Given y-values (1 to 40)
y_values = np.arange(1, 41)

# Assume x-values are evenly spaced with an interval of 1
x_values = np.arange(len(y_values))

# Filter values where y >= 30
x_values_filtered = x_values[y_values >= 30]
y_values_filtered = y_values[y_values >= 30]

# Calculate the AUC for the filtered values using a fixed interval of 1
filtered_auc = np.trapz(y_values_filtered, dx=10)
filtered_auc
# Out:
# 3500.0

# %%
import numpy as np

# Define x and y values from 1 to 40
x_values = np.arange(0, 0)
y_values = np.arange(1, 30)

# Calculate the AUC using the trapezoidal rule
auc = np.trapz(y_values)
auc
# Out:
# 420.0

# %%
420.0-319.5
# Out:
# 100.5
